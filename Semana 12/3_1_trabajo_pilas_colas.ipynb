# %% [markdown]
# Trabajo Práctico Integrador: PILAS y COLAS
#
# En este trabajo desarrollarás dos pequeños sistemas prácticos utilizando las estructuras de datos pilas y colas con prioridad, aplicados a situaciones reales.
#
# ---

# %% [markdown]
# Parte 1: Gestor de Tareas (PILAS)
#
# Simulación de tareas de un empleado:
#
# - Cuando el empleado recibe una nueva tarea, la agrega a la pila.
# - Al terminar una tarea, la elimina de la pila (desapilar).
# - Puede consultar la tarea actual (última en la pila).
# - Simular al menos 10 tareas.
#
# Métodos sugeridos:
# - agregar_tarea(tarea)
# - terminar_tarea()
# - ver_ultima_tarea()
# - tamaño()
#
# Desarrolla aquí tu clase PILA:

# %%
class PilaTareas:
    def __init__(self):
        self.items = []
        
    def agregar_tarea(self, tarea):
        pass
        
    def terminar_tarea(self):
        pass
        
    def ver_ultima_tarea(self):
        pass
        
    def tamaño(self):
        pass

# %% [markdown]
# Simulación de tareas
# Agrega aquí las tareas y muestra cómo funciona tu pila:

# %%
# Crea la instancia y simula 10 tareas
# pila = PilaTareas()
# pila.agregar_tarea("... tarea ...")

# %% [markdown]
# ---
# Parte 2: Atención de Clientes (COLAS CON PRIORIDAD)
#
# Simulación de clientes que llegan a una empresa:
#
# - Cada cliente tiene un nombre y prioridad (1 = más urgente, 4 = menos urgente).
# - Se atienden siempre los clientes de mayor prioridad primero.
# - Simular al menos 8 clientes.
#
# Métodos sugeridos:
# - agregar_cliente(nombre, prioridad)
# - atender_cliente()
# - mostrar_pendientes()
# - tamaño()
#
# Desarrolla aquí tu clase COLA:

# %%
class ColaPrioridadClientes:
    def __init__(self):
        self.items = []
        
    def agregar_cliente(self, nombre, prioridad):
        pass
        
    def atender_cliente(self):
        pass
        
    def mostrar_pendientes(self):
        pass
        
    def tamaño(self):
        pass

# %% [markdown]
# Simulación de clientes
# Agrega aquí los clientes y simula el proceso de atención:

# %%
# Crea la instancia y simula 8 clientes
# cola = ColaPrioridadClientes()
# cola.agregar_cliente("... nombre ...", prioridad)

# %% [markdown]
# ---
# Reflexión final
#
# Explica en tus propias palabras: ¿Qué diferencias observas entre el funcionamiento de una PILA y una COLA CON PRIORIDAD?

# %% [markdown]
# ---
# Rúbrica de Evaluación (Total 100 puntos)
#
# | Criterio | Puntaje máximo |
# |----------|----------------|
# | Implementación de clase PilaTareas completa y funcional | 20 pts |
# | Implementación de clase ColaPrioridadClientes completa y funcional | 20 pts |
# | Correcto funcionamiento de los métodos de cada estructura | 20 pts |
# | Simulación con la cantidad de datos solicitada (10 tareas y 8 clientes) | 10 pts |
# | Uso correcto de listas, bucles y condicionales | 10 pts |
# | Comentarios claros en el código | 10 pts |
# | Explicación final de diferencias entre pila y cola | 5 pts |
# | Presentación ordenada y legible del código | 5 pts |
# | Total | 100 pts |
